# %% [markdown]
# # Distribution Plot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Data mining & ML/ford.csv')

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
sns.distplot(df['price'])
# Out:
# <ipython-input-5-86c1ddc3c66a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['price'],hist=False)
# Out:
# <ipython-input-6-d736fcca5d1e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],hist=False)
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['price'],kde=False)
# Out:
# <ipython-input-7-6a6bd03b19a7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],kde=False)
# <Axes: xlabel='price'>

# %%
sns.jointplot(x='price',y='mileage',data=df,kind='scatter')

# %%
sns.jointplot(x='price',y='mileage',data=df,kind='scatter',hue='transmission')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='transmission',palette='coolwarm')

# %%
sns.pairplot(df,hue='model',palette='rainbow')

# %%
sns.pairplot(df,hue='transmission',palette='rainbow')

# %% [markdown]
# # Categorical Data Plots

# %%
sns.barplot(x='transmission',y='price',data=df)
# Out:
# <Axes: xlabel='transmission', ylabel='price'>

# %%
sns.countplot(x='fuelType',data=df)
# Out:
# <Axes: xlabel='fuelType', ylabel='count'>

# %%
sns.countplot(x='fuelType',data=df,hue="transmission")
# Out:
# <Axes: xlabel='fuelType', ylabel='count'>

# %% [markdown]
# # Matrix Plots

# %%
df.head()

# %%
# Select numerical columns and calculate the correlation matrix
numerical_df = df.select_dtypes(include=['number'])
corr_matrix = numerical_df.corr()

# Generate the heatmap

# %%
numerical_df
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 0      2017  12000    15944  150  57.7         1.0
# 1      2018  14000     9083  150  57.7         1.0
# 2      2017  13000    12456  150  57.7         1.0
# 3      2019  17500    10460  145  40.3         1.5
# 4      2019  16500     1482  145  48.7         1.0
# ...     ...    ...      ...  ...   ...         ...
# 17961  2017   8999    16700  150  47.1         1.4
# 17962  2014   7499    40700   30  57.7         1.0
# 17963  2015   9999     7010   20  67.3         1.6
# 17964  2018   8299     5007  145  57.7         1.2
# 17965  2015   8299     5007   22  57.7         1.0
#
# [17966 rows x 6 columns]

# %%
corr_matrix
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.636009 -0.707818  0.298506 -0.022967   -0.137311
# price       0.636009  1.000000 -0.530659  0.406857 -0.346419    0.411178
# mileage    -0.707818 -0.530659  1.000000 -0.260451  0.120075    0.215035
# tax         0.298506  0.406857 -0.260451  1.000000 -0.502980    0.184363
# mpg        -0.022967 -0.346419  0.120075 -0.502980  1.000000   -0.260521
# engineSize -0.137311  0.411178  0.215035  0.184363 -0.260521    1.000000

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
sns.heatmap(corr_matrix.corr(),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Grids

# %%
g = sns.PairGrid(df)
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(df)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(df,hue="transmission")
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
